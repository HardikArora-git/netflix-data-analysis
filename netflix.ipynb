# %% [markdown]
# <a href="https://colab.research.google.com/gist/HardikArora-git/f84a8c67f5eb9e1e6933a002eea6e11a/netflix.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

print("Libraries loaded")

# %%
from google.colab import files
uploaded = files.upload()

# %%
df = pd.read_csv('netflix_titles.csv')
df.head()

# %%
df.info()
df.shape
df.isnull().sum()
df.columns
df.describe()

# %%
df['type'].value_counts()

# %%
sns.countplot(x='type', data=df)
plt.show()

# %%
df['type'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.show()

# %%
df['country'].value_counts().head(10)

# %%
df['type'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.show()

# %%
df['release_year'].value_counts().sort_index().plot(figsize=(15,5))
plt.show()

# %%
df['listed_in'].value_counts().head(10).plot(kind='barh')
plt.title("Top Genres")
plt.show()
